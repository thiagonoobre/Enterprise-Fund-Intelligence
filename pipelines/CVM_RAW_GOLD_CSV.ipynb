# %%
import requests
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql import types as t
from pyspark.sql.window import Window
import requests, zipfile, io
import re
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from datetime import date
import pprint
import os

# %% [markdown]
# ### CVM Fundos diarios

# %%
df_cvm_fundos_diario = spark.table("workspace.case_spark_cvm.silver_cvm_fundos_diario")

df_cvm_fundos_diario.orderBy(f.desc('CNPJ_FUNDO_CLASSE')).show()

# %%
df_silver_cvm_fundos_diario.groupBy('ID_SUBCLASSE').count().show()

# %% [markdown]
# ### CVM Registros de Classe

# %%
df_registro_classe_cvm = spark.table("workspace.case_spark_cvm.silver_registro_classe_cvm")

df_registro_classe_cvm.show()              #limit(5).toPandas()

# %%
df_registro_classe_cvm.filter(f.col('CNPJ_Classe') == '97929213000134' ).limit(5).toPandas()

# %% [markdown]
# ### CVM Registros de Subclasse

# %%
df_registro_subclasse_cvm = spark.table("workspace.case_spark_cvm.silver_registro_subclasse_cvm")

df_registro_subclasse_cvm.show()        #limit(5).toPandas()

# %% [markdown]
# ### CVM Registros de Fundos

# %%
df_registro_fundo_cvm = spark.table("workspace.case_spark_cvm.silver_registro_fundo_cvm")

df_registro_fundo_cvm.show()      #limit(5).toPandas()
