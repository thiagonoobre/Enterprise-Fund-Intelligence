# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql.functions import date_format
from pyspark.sql import types as t
from pyspark.sql.window import Window
from datetime import datetime

# %%
df_temp = spark.read.csv("/Volumes/workspace/case_spark_cvm/raw/cvm_informe_diario/inf_diario_fi_202412.csv", sep=';', header=True)

# %%
df_temp = df_temp.filter(f.col('CNPJ_FUNDO_CLASSE') == '29.550.273/0001-91')\
  .select("DT_COMPTC", "VL_QUOTA")\
  .orderBy("dt_comptc")

# %%
display(df_temp)
